# %%
from cs2d import csd
import warnings
warnings.filterwarnings("ignore")

traindata, trainlabel, testdata, testlabel = csd.linear_data(4000,1000)
backdoor_target = 1
number_of_bd = 50

# %% [markdown]
# ### We create linear classifier and associated selection method

# %%
### classifier and selection mechanism
cs2d_classifier = Linearclassifier
cs2d_selection = Synselection

# %% [markdown]
# ### Fit the model

# %%
cs2d_classifier = cs2d(cs2d_classifier, cs2d_selection)
cs2d_classifier.fit(traindata, trainlabel, backdoor_target, number_of_bd)

# %% [markdown]
# ### Check predicition result

# %%
## normal score
cs2d_classifier.score(testdata,ytest)
# Out:
# 0.951

# %%
## backdoor accuracy
cs2d_classifier.backdoor_score(testdata, backdoor_target)
# Out:
# 0.9787

# %% [markdown]
# ### Check those selected index

# %%
backdoor_selection(testdata, cutoff, ratio = 0.05)
# Out:
# tensor([  13,   19,   31,   55,   59,   65,   85,   96,  105,  107,  108,  129,
#          142,  148,  151,  167,  177,  182,  191,  213,  235,  243,  244,  274,
#          303,  336,  339,  342,  346,  378,  386,  394,  404,  413,  416,  418,
#          422,  428,  429,  438,  454,  457,  474,  483,  507,  509,  515,  518,
#          521,  530,  544,  548,  560,  574,  590,  599,  601,  604,  606,  613,
#          630,  632,  633,  638,  639,  644,  649,  658,  669,  674,  678,  690,
#          703,  708,  722,  724,  726,  727,  741,  757,  761,  765,  766,  771,
#          777,  795,  807,  832,  858,  859,  871,  879,  884,  891,  900,  901,
#          926,  929,  957, 1011, 1016, 1020, 1028, 1041, 1068, 1069, 1073, 1091,
#         1119, 1122, 1134, 1141, 1156, 1157, 1158, 1169, 1173, 1178, 1185, 1191,
#         1202, 1209, 1211, 1214, 1218, 1224, 1235, 1262, 1275, 1283, 1288, 1313,
#         1322, 1323, 1337, 1352, 1376, 1393, 1401, 1405, 1412, 1425, 1450, 1456,
#         1466, 1495, 1511, 1518, 1522, 1523, 1530, 1533, 1538, 1544, 1551, 1558,
#         1560, 1562, 1588, 1589, 1592, 1593, 1605, 1659, 1673, 1675, 1685, 1694,
#         1695, 1714, 1768, 1788, 1807, 1813, 1815, 1824, 1834, 1846, 1848, 1855,
#         1859, 1861, 1913, 1922, 1958, 1985, 1996, 1999])

# %%
### plotting module
